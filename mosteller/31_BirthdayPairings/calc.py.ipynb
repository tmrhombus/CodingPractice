# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 365
ns = [i for i in range(1,N+1)]
ps = []

# %%
thep = 1
for i in ns:
    #print(i)
    thep = thep * (N+1-i)/(N)
    ps.append(1-thep)

# %%
figw = 10
figh = 5
nbins = 14

c_base = "#012155"
c_hist = "teal" #"black"
fs = 20
lw = 3

title = "Probability of at least one Birthday Pair"
ytitle = "Probability"
xtitle = "Nr. People"

fig, ax1 = plt.subplots(1, 1, figsize = (figw, figh))

ax1.set_title(title, fontsize=fs+5, loc="left", color=c_base)
ax1.set_ylabel(ytitle, fontsize=fs, color=c_base)
ax1.set_xlabel(xtitle, fontsize=fs, color=c_base)
ax1.tick_params( axis="both", which="major", labelsize=fs-5, colors=c_base )

ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["bottom"].set_color(c_base)
ax1.spines["left"].set_color(c_base)

ax1.plot( ns, ps, linewidth=lw, color=c_hist )

ax1.axhline(0.5, lw=lw, color="black", linestyle=":")
#ax1.axvline( avg_n_pairs, lw=lw, color=c_hist, linestyle=":" )

# %%
figw = 10
figh = 5
nbins = 14

c_base = "#012155"
c_hist = "teal" #"black"
fs = 20
lw = 3

title = "Probability of at least one Birthday Pair"
ytitle = "Probability"
xtitle = "Nr. People"

fig, ax1 = plt.subplots(1, 1, figsize = (figw, figh))

ax1.set_title(title, fontsize=fs+5, loc="left", color=c_base)
ax1.set_ylabel(ytitle, fontsize=fs, color=c_base)
ax1.set_xlabel(xtitle, fontsize=fs, color=c_base)
ax1.tick_params( axis="both", which="major", labelsize=fs-5, colors=c_base )

ax1.spines["top"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.spines["bottom"].set_color(c_base)
ax1.spines["left"].set_color(c_base)

ax1.plot( ns[:30], ps[:30], linewidth=lw, color=c_hist )

ax1.axhline(0.5, lw=lw, color="black", linestyle=":")
ax1.axvline(22, lw=lw, color="blue", linestyle=":")
ax1.axvline(23, lw=lw, color="blue", linestyle=":")
